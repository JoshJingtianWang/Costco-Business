# %% [markdown]
# # Scraping Costco Warehouse Location Data

# %%
import pandas as pd
import requests, bs4, re
from bs4 import BeautifulSoup as bs
from time import sleep
from selenium import webdriver

# %%
d = webdriver.Chrome()
d.get('https://www.costco.com/WarehouseListByStateDisplayView')
sleep(10)
#d.close()

# %%
b=d.find_element_by_link_text("Louisiana") #https://www.geeksforgeeks.org/click-button-by-text-using-python-and-selenium/
b.click()
sleep(2)
# Out:
# <ipython-input-3-9a5bb8caaf77>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   b=d.find_element_by_link_text("Louisiana") #https://www.geeksforgeeks.org/click-button-by-text-using-python-and-selenium/

# %%
s = bs(d.page_source, 'html.parser').find("div", {"id": "warehouse-by-state-accordion-collapse-panel"})
stores=s.find_all("div")

# %%
for store in stores:
    if store.has_attr('data-warehouse'):
        #storename=store.find('a', {"class": "warehouse-name h6-style-guide-link"}).text
        #print(storename)
        storeaddress=store.find('div', {"class": "h6-style-guide"})
        print(storeaddress.next.strip())
        print(storeaddress.next.next.next.strip())
        print(storeaddress.next.next.next.strip().split(',')[0])
        print(storeaddress.next.next.next.strip().split()[1])
        print(storeaddress.next.next.next.strip().split()[-1])
        #storeaddress=' '.join(storeaddress.split())
        #print(repr(storeaddress))
        #print(storeaddress)
        #storephone=store.find('a', {"class": "body-copy-link"}).text
        #print(storephone)
        #icons=store.find_all('i')
        #for icon in icons:
            #print(icon.attrs['class'][0])
        #print('-----------------------------')
        break
# Out:
# 2355 COSTCO WAY
# BELLEVUE, WI 54311-9206
# BELLEVUE
# WI
# 54311-9206

# %%
states = {
    'AK': 'Alaska',
    'AL': 'Alabama',
    'AR': 'Arkansas',
    'AZ': 'Arizona',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DC': 'District of Columbia',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'IA': 'Iowa',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'MA': 'Massachusetts',
    'MD': 'Maryland',
    'ME': 'Maine',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MO': 'Missouri',
    'MS': 'Mississippi',
    'MT': 'Montana',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'NE': 'Nebraska',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NV': 'Nevada',
    'NY': 'New York',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'PR': 'Puerto Rico',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VA': 'Virginia',
    'VT': 'Vermont',
    'WA': 'Washington',
    'WI': 'Wisconsin',
    'WV': 'West Virginia',
    'WY': 'Wyoming'
}
states=list(states.values())

# %%
storelocations={}

for state in states:
    
    b=d.find_element_by_link_text(state) #https://www.geeksforgeeks.org/click-button-by-text-using-python-and-selenium/
    b.click()
    sleep(2)
    s = bs(d.page_source, 'html.parser').find("div", {"id": "warehouse-by-state-accordion-collapse-panel"})
    stores=s.find_all("div")
    
    for store in stores:
        if store.has_attr('data-warehouse'):
            
            storename=store.find('a', {"class": "warehouse-name h6-style-guide-link"}).text
            statestorename=state+'_'+storename
            storelocations[statestorename]={}
            
            storeaddress=store.find('div', {"class": "h6-style-guide"}).text
            streetaddress=storeaddress.next.strip()
            city=storeaddress.next.next.next.strip().split(',')[0]
            zipcode=storeaddress.next.next.next.strip().split()[-1]
            storelocations[statestorename]['streetaddress']=streetaddress
            storelocations[statestorename]['city']=city
            storelocations[statestorename]['state']=state
            storelocations[statestorename]['zipcode']=zipcode
            
            storephone=store.find('a', {"class": "body-copy-link"}).text
            storelocations[statestorename]['phonenumber']=storephone
            
            icons=store.find_all('i')
            iconlist=[]
            for icon in icons:
                iconlist.append(icon.attrs['class'][0]
            if 'wl-food-court' in iconlist:
# Out:
# <ipython-input-47-b8247f64c9c3>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   b=d.find_element_by_link_text(state) #https://www.geeksforgeeks.org/click-button-by-text-using-python-and-selenium/
# Anchorage
#       330 W DIMOND BLVD      ANCHORAGE, AK 99515-1950
# (907) 349-2335
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Fairbanks
#       48 COLLEGE RD      FAIRBANKS, AK 99701-1706
# (907) 205-3607
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Juneau
#       5225 COMMERCIAL BLVD      JUNEAU, AK 99801-7210
# (907) 780-6740
# wl-food-court
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# NE Anchorage
#       4125 DEBARR RD      ANCHORAGE, AK 99508-3115
# (907) 269-9510
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Hoover
#       3650 GALLERIA CIR      HOOVER, AL 35244-2346
# (205) 909-1039
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Huntsville
#       1205 N. MEMORIAL PKWY      HUNTSVILLE, AL 35801-5930
# (256) 519-2220
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Mobile
#       1450 TINGLE CIRCLE WEST      MOBILE, AL 36606-2632
# (251) 308-7030
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Montgomery
#       8251 EASTCHASE PKWY      MONTGOMERY, AL 36117-7033
# (334) 270-7452
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Little Rock
#       16901 CHENAL PARKWAY      LITTLE ROCK, AR 72223
# (501) 817-8603
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Avondale
#       10000 W MCDOWELL RD      AVONDALE, AZ 85392-4803
# (623) 907-5663
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Cave Creek
#       2450 E BEARDSLEY RD      PHOENIX, AZ 85050-1300
# (480) 375-2850
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Chandler
#       595 S GALLERIA WAY      CHANDLER, AZ 85226-4932
# (480) 375-2051
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Gilbert
#       1415 N ARIZONA AVE      GILBERT, AZ 85233-1616
# (480) 293-0053
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Glendale
#       17550 N 79TH AVE      GLENDALE, AZ 85308-8711
# (623) 776-4003
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Mesa
#       1444 S SOSSAMAN RD      MESA, AZ 85209-3400
# (480) 333-6552
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# N Phoenix
#       19001 N 27TH AVE      PHOENIX, AZ 85027-5036
# (623) 293-4400
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# NW Tucson
#       3901 W COSTCO DR      TUCSON, AZ 85741-2864
# (520) 797-1980
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Paradise Valley
#       4570 E CACTUS RD      PHOENIX, AZ 85032-7702
# (480) 308-7044
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Phoenix Business Center
#       3801 N 33RD AVE      PHOENIX, AZ 85017-4508
# (480) 293-2123
# wl-business
# wl-gas-station
# -----------------------------
# Prescott
#       3911 E STATE ROUTE 69      PRESCOTT, AZ 86301-6717
# (928) 541-2203
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# SE Gilbert
#       2887 S MARKET ST      GILBERT, AZ 85295-1303
# (480) 366-3950
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# SW Tucson
#       1650 E TUCSON MARKETPLACE BLVD      TUCSON, AZ 85713-6561
# (520) 791-7340
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Scottsdale
#       15255 N HAYDEN RD      SCOTTSDALE, AZ 85260-2507
# (480) 948-5040
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Surprise
#       16385 W. WADDELL RD.      SURPRISE, AZ 85388
# (602) 325-1799
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Tempe
#       1445 W ELLIOT RD      TEMPE, AZ 85284-1103
# (480) 496-6651
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Thomas Road
#       4502 E OAK ST      PHOENIX, AZ 85008-2411
# (602) 808-0101
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Tucson
#       6255 EAST GRANT ROAD      TUCSON, AZ 85712-5834
# (520) 886-6377
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Alhambra
#       2207 W COMMONWEALTH AVE      ALHAMBRA, CA 91803-1302
# (626) 289-7164
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Almaden
#       5301 ALMADEN EXPY      SAN JOSE, CA 95118-3603
# (408) 723-0964
# wl-food-court
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Antioch
#       2201 VERNE ROBERTS CIR      ANTIOCH, CA 94509-7911
# (925) 757-7130
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Azusa
#       1220 W FOOTHILL BLVD      AZUSA, CA 91702-2819
# (626) 812-7911
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Bakersfield
#       3800 ROSEDALE HWY      BAKERSFIELD, CA 93308-6235
# (661) 852-2643
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Burbank
#       1051 W BURBANK BLVD      BURBANK, CA 91506-1421
# (818) 557-3783
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Burbank Business Center
#       11428 SHERMAN WAY      NORTH HOLLYWOOD, CA 91605-5807
# (818) 423-7082
# wl-business
# wl-food-court
# -----------------------------
# Cal Expo (Sacramento)
#       1600 EXPO PKWY      SACRAMENTO, CA 95815-4228
# (916) 830-1078
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Carlsbad
#       951 PALOMAR AIRPORT RD      CARLSBAD, CA 92011-1110
# (760) 929-0963
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Carmel Mountain
#       12350 CARMEL MOUNTAIN RD      SAN DIEGO, CA 92128-4697
# (858) 675-0379
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Chico
#       2100 DR MLK JR PKWY      CHICO, CA 95928-4422
# (530) 332-1742
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Chino Hills
#       13111 PEYTON DR      CHINO HILLS, CA 91709-6002
# (909) 464-2900
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Chula Vista
#       1130 BROADWAY      CHULA VISTA, CA 91911-2707
# (619) 205-1501
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Citrus Heights
#       7000 AUBURN BLVD      CITRUS HEIGHTS, CA 95621-4342
# (916) 560-4003
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# City Of Industry
#       17550 CASTLETON ST      CITY OF INDUSTRY, CA 91748-1701
# (626) 839-3053
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Clovis
#       2270 CLOVIS AVE      CLOVIS, CA 93612
# (559) 291-3377
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Commerce Business Center
#       6333 TELEGRAPH RD      COMMERCE, CA 90040-2513
# (323) 767-2640
# wl-business
# wl-food-court
# wl-gas-station
# -----------------------------
# Concord
#       2400 MONUMENT BLVD      CONCORD, CA 94520-3105
# (925) 566-4003
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Corona
#       480 N MCKINLEY ST      CORONA, CA 92879-1291
# (951) 279-1190
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Culver City
#       13463 WASHINGTON BLVD      MARINA DEL REY, CA 90292-5658
# (310) 754-2003
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Cypress CA
#       5401 KATELLA AVE      CYPRESS, CA 90720-2809
# (562) 668-5150
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Danville
#       3150 FOSTORIA WAY      DANVILLE, CA 94526-5553
# (925) 277-0407
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Eastvale
#       5030 HAMNER AVE      EASTVALE, CA 91752-1009
# (951) 749-7182
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Orlando Business Center
#       2101 WATERBRIDGE BLVD      ORLANDO, FL 32837-9283
# (407) 586-7271
# wl-business
# wl-gas-station
# -----------------------------
# Palm Beach Gardens
#       3250 NORTHLAKE BLVD      PALM BEACH GARDENS, FL 33403-1702
# (561) 776-3052
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Pembroke Pines
#       15915 PINES BLVD      PEMBROKE PINES, FL 33027-1201
# (954) 266-3460
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Pompano
#       1800 W SAMPLE RD      POMPANO BEACH, FL 33064-1324
# (954) 968-7114
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Royal Palm Beach
#       11001 SOUTHERN BLVD      ROYAL PALM BEACH, FL 33411-4240
# (561) 803-8822
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# S Orlando
#       4696 GARDENS PARK BLVD      ORLANDO, FL 32839-2171
# (407) 586-7221
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Sarasota Mall
#       8201 S TAMIAMI TRL UNIT 501      SARASOTA, FL 34238-2966
# (941) 554-2800
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Tallahassee
#       4067 LAGNIAPPE WAY      TALLAHASSEE, FL 32317-1201
# (850) 219-2500
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# W Jacksonville
#       8000 PARRAMORE RD      JACKSONVILLE, FL 32244-5704
# (904) 479-7521
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# W Tampa
#       8712 W LINEBAUGH AVE      TAMPA, FL 33625-3713
# (813) 616-7001
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Wesley Chapel
#       2225 GRAND CYPRESS DR      LUTZ, FL 33559-6797
# (813) 279-7031
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Alpharetta
#       2855 JORDAN CT      ALPHARETTA, GA 30004-3869
# (678) 823-4950
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Augusta
#       825 CABELA DR      AUGUSTA, GA 30909-8202
# (706) 739-1700
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Brookhaven
#       500 BROOKHAVEN AVE NE      ATLANTA, GA 30319-3291
# (404) 460-1915
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Cumberland Mall
#       2900 CUMBERLAND MALL SE      ATLANTA, GA 30339-8107
# (770) 431-1700
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Cumming
#       1211 BALD RIDGE MARINA RD      CUMMING, GA 30041-8484
# (470) 239-6610
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Dallas GA
#       1715 CHARLES HARDY PKWY      DALLAS, GA 30157
# (404) 806-4595
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Fort Oglethorpe
#       100 COBB PKWY      RINGGOLD, GA 30736-8566
# (706) 891-2579
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Gwinnett
#       3980 VENTURE DR      DULUTH, GA 30096-5077
# (770) 622-1330
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Mall Of Georgia
#       1550 MALL OF GEORGIA BLVD      BUFORD, GA 30519-6551
# (678) 288-3009
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Morrow Business Center
#       1700 MOUNT ZION RD      MORROW, GA 30260-3014
# (678) 201-0003
# wl-business
# wl-gas-station
# -----------------------------
# Perimeter
#       6350 PEACHTREE DUNWOODY RD      ATLANTA, GA 30328-4527
# (770) 352-8660
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Pooler
#       200 MOSAIC CIRCLE      POOLER, GA 31322
# (912) 348-4569
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Sharpsburg
#       40 FISCHER CROSSINGS DR      SHARPSBURG, GA 30277
# (678) 621-8594
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Town Center
#       645 BARRETT PARKWAY NW      KENNESAW, GA 30144-4922
# (770) 794-1767
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Woodstock
#       113 LINCOLN ST      WOODSTOCK, GA 30188-7800
# (770) 694-7193
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Hawaii Kai
#       333 A KEAHOLE STREET      HONOLULU, HI 96825-3404
# (808) 396-5538
# wl-food-court
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Iwilei
#       525 ALAKAWA ST      HONOLULU, HI 96817-5764
# (808) 526-6100
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Kapolei
#       4589 KAPOLEI PKWY      KAPOLEI, HI 96707-1879
# (808) 674-3900
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Kauai
#       4300 NUHOU ST.      LIHUE, HI 96766-8002
# (808) 241-4000
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
#
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Kennewick
#       8505 W. GAGE BLVD      KENNEWICK, WA 99336-8120
# (509) 737-8861
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Kirkland
#       8629 120TH AVE NE      KIRKLAND, WA 98033-5865
# (425) 827-1693
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Lacey
#       1470 MARVIN RD NE      LACEY, WA 98516-3870
# (360) 412-3500
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Lynnwood
#       18109 33RD AVE W      LYNNWOOD, WA 98037-4840
# (425) 697-1062
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Lynnwood Business Center
#       19105 HIGHWAY 99      LYNNWOOD, WA 98036-5228
# (425) 640-7700
# wl-business
# wl-gas-station
# -----------------------------
# Marysville
#       16616 TWIN LAKES AVE      MARYSVILLE, WA 98271-4701
# (360) 652-4532
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# N Spokane
#       12020 N NEWPORT HWY      SPOKANE, WA 99218-1655
# (509) 466-9668
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Puyallup
#       1201 39TH AVE SW      PUYALLUP, WA 98373-3803
# (253) 445-7543
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Redmond
#       7725 188TH AVE NE      REDMOND, WA 98052-6088
# (425) 406-5382
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Seattle
#       4401 4TH AVE S      SEATTLE, WA 98134-2389
# (206) 622-3136
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Sequim
#       955 W WASHINGTON ST      SEQUIM, WA 98382-3266
# (360) 406-2025
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Silverdale
#       10000 MICKELBERRY RD NW      SILVERDALE, WA 98383-8302
# (360) 692-9213
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Spokane
#       5601 E SPRAGUE AVE      SPOKANE, WA 99212-0826
# (509) 842-0003
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Tacoma
#       2219 S 37TH ST      TACOMA, WA 98409-7473
# (253) 475-5595
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Tukwila
#       400 COSTCO DR STE 150      TUKWILA, WA 98188-4808
# (206) 575-9191
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Tumwater
#       5500 LITTLEROCK RD SW      TUMWATER, WA 98512-7363
# (360) 357-6580
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Union Gap
#       2310 LONGFIBRE RD      UNION GAP, WA 98903-1513
# (509) 454-5242
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Vancouver WA
#       6720 NE 84TH ST      VANCOUVER, WA 98665-2016
# (360) 828-2262
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Wenatchee
#       375 HIGHLINE DR      EAST WENATCHEE, WA 98802-5344
# (509) 886-0593
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Woodinville
#       24008 SNOHOMISH WOODINVILLE RD      WOODINVILLE, WA 98072-9743
# (425) 806-7700
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Bellevue (Green Bay)
#       2355 COSTCO WAY      BELLEVUE, WI 54311-9206
# (920) 469-5700
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Grafton
#       950 PORT WASHINGTON RD      GRAFTON, WI 53024-9201
# (262) 204-1050
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Grand Chute
#       5401 W. INTEGRITY WAY      GRAND CHUTE, WI 54913-8602
# (920) 815-4500
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Menomonee Falls
#       W162N9235 PERSHING AVE      MENOMONEE FALLS, WI 53051-4026
# (262) 946-6060
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Middleton
#       2150 DEMING WAY      MIDDLETON, WI 53562-5507
# (608) 824-3950
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# New Berlin
#       15300 WEST GRANGE AVE      NEW BERLIN, WI 53151-7909
# (262) 599-7030
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Pewaukee
#       443 PEWAUKEE RD      PEWAUKEE, WI 53072-5886
# (262) 956-6700
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Pleasant Prairie
#       7707 94TH AVE      PLEASANT PRAIRIE, WI 53158-1955
# (262) 597-1027
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Sun Prairie
#       2850 HOEPKER RD      SUN PRAIRIE, WI 53590-9334
# (608) 825-4001
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Bellevue (Green Bay)
#       2355 COSTCO WAY      BELLEVUE, WI 54311-9206
# (920) 469-5700
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Grafton
#       950 PORT WASHINGTON RD      GRAFTON, WI 53024-9201
# (262) 204-1050
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Grand Chute
#       5401 W. INTEGRITY WAY      GRAND CHUTE, WI 54913-8602
# (920) 815-4500
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Menomonee Falls
#       W162N9235 PERSHING AVE      MENOMONEE FALLS, WI 53051-4026
# (262) 946-6060
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Middleton
#       2150 DEMING WAY      MIDDLETON, WI 53562-5507
# (608) 824-3950
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# New Berlin
#       15300 WEST GRANGE AVE      NEW BERLIN, WI 53151-7909
# (262) 599-7030
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Pewaukee
#       443 PEWAUKEE RD      PEWAUKEE, WI 53072-5886
# (262) 956-6700
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Pleasant Prairie
#       7707 94TH AVE      PLEASANT PRAIRIE, WI 53158-1955
# (262) 597-1027
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Sun Prairie
#       2850 HOEPKER RD      SUN PRAIRIE, WI 53590-9334
# (608) 825-4001
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Bellevue (Green Bay)
#       2355 COSTCO WAY      BELLEVUE, WI 54311-9206
# (920) 469-5700
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Grafton
#       950 PORT WASHINGTON RD      GRAFTON, WI 53024-9201
# (262) 204-1050
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Grand Chute
#       5401 W. INTEGRITY WAY      GRAND CHUTE, WI 54913-8602
# (920) 815-4500
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Menomonee Falls
#       W162N9235 PERSHING AVE      MENOMONEE FALLS, WI 53051-4026
# (262) 946-6060
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Middleton
#       2150 DEMING WAY      MIDDLETON, WI 53562-5507
# (608) 824-3950
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# New Berlin
#       15300 WEST GRANGE AVE      NEW BERLIN, WI 53151-7909
# (262) 599-7030
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Pewaukee
#       443 PEWAUKEE RD      PEWAUKEE, WI 53072-5886
# (262) 956-6700
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Pleasant Prairie
#       7707 94TH AVE      PLEASANT PRAIRIE, WI 53158-1955
# (262) 597-1027
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------
# Sun Prairie
#       2850 HOEPKER RD      SUN PRAIRIE, WI 53590-9334
# (608) 825-4001
# wl-food-court
# wl-gas-station
# wl-hearing-aid
# wl-optical
# wl-rx
# wl-tire-center
# -----------------------------

# %%
states
# Out:
# ['Alaska',
#  'Alabama',
#  'Arkansas',
#  'Arizona',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'District of Columbia',
#  'Delaware',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Iowa',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Massachusetts',
#  'Maryland',
#  'Maine',
#  'Michigan',
#  'Minnesota',
#  'Missouri',
#  'Mississippi',
#  'Montana',
#  'North Carolina',
#  'North Dakota',
#  'Nebraska',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'Nevada',
#  'New York',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Puerto Rico',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Virginia',
#  'Vermont',
#  'Washington',
#  'Wisconsin',
#  'West Virginia',
#  'Wyoming']

# %%
d.close()

# %%
rows=[[i.text.strip() for i in b.find_all('td')] for b in s.find_all('tr')]
rows = [i for i in rows if len(i) > 1]
rowsdf=pd.DataFrame(rows)
rowsdf=rowsdf.iloc[:,subcolumns]
rowsdf.columns=columnnames
rowsdf['Year'] = year
